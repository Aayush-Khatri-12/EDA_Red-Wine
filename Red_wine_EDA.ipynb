# %% [markdown]
# <a href="https://colab.research.google.com/github/Aayush-Khatri-12/EDA__Red_Wine/blob/main/Red_wine_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
#
# # EXPLORATORY DATA ANALYSIS PRACTICE
#
#
# ---

# %% [markdown]
# ## 1. Importing the required libraries for EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Loading the data into the data frame.

# %%
df = pd.read_csv("/content/winequality-red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# ## 3. Checking the types of data

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# ## 4. Dropping irrelevant columns

# %%
c=df.columns
c
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
y=[]
for i in range(len(c)):
  y.append(len(pd.unique(df[c[i]])))
y
# Out:
# [96, 143, 80, 91, 153, 60, 144, 436, 89, 96, 65, 6]

# %% [markdown]
# Thus all the columns are useful
#
# No need to drop

# %% [markdown]
# ## 6. Dropping the duplicate rows

# %%
df.shape
# Out:
# (1599, 12)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (240, 12)

# %%
df.count()
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %%
df = df.drop_duplicates()
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.count()
# Out:
# fixed acidity           1359
# volatile acidity        1359
# citric acid             1359
# residual sugar          1359
# chlorides               1359
# free sulfur dioxide     1359
# total sulfur dioxide    1359
# density                 1359
# pH                      1359
# sulphates               1359
# alcohol                 1359
# quality                 1359
# dtype: int64

# %% [markdown]
# ## 7. Dropping the missing or null values.

# %%
print(df.isnull().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## 8. Detecting Outliers

# %%
for i in range(len(c)-1):
  sns.boxplot(x=df[c[i]])
  plt.subplot(3,4,i+1)
# Out:
# <ipython-input-45-abbac4896dcf>:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,4,i+1)

# %% [markdown]
# ## 9. Plot different features against one another

# %%
plt.figure(figsize=(14,6))
for i in range(len(x)-1):
  sns.scatterplot(x=df[c[i]],y=df['quality'])
  plt.subplot(3,4,i+1)
# Out:
# <ipython-input-48-c6a825f36d35>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,4,i+1)

# %%
plt.figure(figsize=(14,6))
for i in range(len(x)-1):
  sns.lineplot(x=df[c[i]],y=df['quality'])
  plt.subplot(3,4,i+1)
# Out:
# <ipython-input-49-5a916e675c6b>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,4,i+1)

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,annot=True)
# Out:
# <Axes: >
